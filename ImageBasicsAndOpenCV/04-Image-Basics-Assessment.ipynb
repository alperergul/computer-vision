# %% [markdown]
# <a href="https://www.pieriandata.com"><img src="../DATA/Logo.jpg"></a>

# %% [markdown]
# # Image Basics Assessment
#
# ## Complete the Tasks in bold below. Keep in mind, you may need to run some of these tasks as Python scripts.

# %% [markdown]
# ----------
# #### TASK: Open the *dog_backpack.jpg* image from the DATA folder and display it in the notebook. Make sure to correct for the RGB order.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('../DATA/dog_backpack.jpg')

# %%
plt.imshow(img)

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %% [markdown]
# #### TASK: Flip the image upside down and display it in the notebook.

# %%
img_flip = cv2.flip(img_rgb, 0)
plt.imshow(img_flip)

# %% [markdown]
# #### TASK: Draw an empty RED rectangle around the dogs face and display the image in the notebook.

# %%
cv2.rectangle(img_rgb, (250,400), (650,650), color=(255,0,0), thickness=5)
plt.imshow(img_rgb)

# %% [markdown]
# #### TASK: Draw a BLUE TRIANGLE in the middle of the image. The size and angle is up to you, but it should be a triangle (three sides) in any orientation.

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
cv2.line(img_rgb, (400,350), (200,700),color=(0,0,255), thickness=10)
cv2.line(img_rgb, (200,700), (650,700) ,color=(0,0,255), thickness=10)

cv2.line(img_rgb, (650,700), (400,350),color=(0,0,255), thickness=10)
plt.imshow(img_rgb)

# %% [markdown]
# #### TASK: (NOTE: YOU WILL NEED TO RUN THIS AS A SCRIPT). Create a script that opens the picture and allows you to draw empty red circles whever you click the RIGHT MOUSE BUTTON DOWN.

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

def draw_cricle(event, x, y, flags, param):
    if event == cv2.EVENT_RBUTTONDOWN:
        cv2.circle(img_rgb, (x,y), radius=50, color=(255,0,0), thickness=10)


cv2.namedWindow(winname='img')

cv2.setMouseCallback(img_rgb, draw_cricle)

while True:

    cv2.imshow('img',img_rgb)

    if cv2.waitKey(1) & 0xFF == 27:

        break
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\alper\AlperProjects\UDEMY\computer_vision\alper_notes\ImageBasicsAndOpenCV\04-Image-Basics-Assessment.ipynb Cell 16 in <cell line: 10>()
#       <a href='vscode-notebook-cell:/c%3A/Users/alper/AlperProjects/UDEMY/computer_vision/alper_notes/ImageBasicsAndOpenCV/04-Image-Basics-Assessment.ipynb#X23sZmlsZQ%3D%3D?line=4'>5</a>         cv2.circle(img_rgb, (x,y), radius=50, color=(255,0,0), thickness=10)
#       <a href='vscode-notebook-cell:/c%3A/Users/alper/AlperProjects/UDEMY/computer_vision/alper_notes/ImageBasicsAndOpenCV/04-Image-Basics-Assessment.ipynb#X23sZmlsZQ%3D%3D?line=7'>8</a> cv2.namedWindow(winname='img')
# ---> <a href='vscode-notebook-cell:/c%3A/Users/alper/AlperProjects/UDEMY/computer_vision/alper_notes/ImageBasicsAndOpenCV/04-Image-Basics-Assessment.ipynb#X23sZmlsZQ%3D%3D?line=9'>10</a> cv2.setMouseCallback(img_rgb, draw_cricle)
#      <a href='vscode-notebook-cell:/c%3A/Users/alper/AlperProjects/UDEMY/computer_vision/alper_notes/ImageBasicsAndOpenCV/04-Image-Basics-Assessment.ipynb#X23sZmlsZQ%3D%3D?line=11'>12</a> while True:
#      <a href='vscode-notebook-cell:/c%3A/Users/alper/AlperProjects/UDEMY/computer_vision/alper_notes/ImageBasicsAndOpenCV/04-Image-Basics-Assessment.ipynb#X23sZmlsZQ%3D%3D?line=13'>14</a>     cv2.imshow('img',img_rgb)
#
# TypeError: argument 1 must be str, not numpy.ndarray
